# %% [markdown]
# <a href="https://colab.research.google.com/github/fat-05/fat-05/blob/main/Untitled55.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone the repository in Colab or Jupyter
# !git clone https://github.com/cadema-PoliTO/Bill2Watt.git
# Out:
# Cloning into 'Bill2Watt'...
# remote: Enumerating objects: 203, done.
# remote: Counting objects: 100% (203/203), done.
# remote: Compressing objects: 100% (148/148), done.
# remote: Total 203 (delta 72), reused 168 (delta 47), pack-reused 0 (from 0)
# Receiving objects: 100% (203/203), 7.86 MiB | 15.25 MiB/s, done.
# Resolving deltas: 100% (72/72), done.

# %%
import sys
sys.path.append('/content/Bill2Watt')  # Add the cloned repo to Python path

# %%
import numpy as np
import pandas as pd
import os
from matplotlib import pyplot as plt

# Bill2Watt modules
from bill2watt.common.common import *
from bill2watt.utils.normalizing import XRowNormalizer, YRowNormalizer

# Plotting helpers
from plotting import create_two_doughnuts, create_aligned_boxplots, create_profile_percentiles

# %%
import os

os.makedirs('/content/Bill2Watt/data', exist_ok=True)

# %%
from google.colab import files

# This will open a file chooser in Colab
uploaded = files.upload()
# Out:
#      <input type="file" id="files-228a7024-422d-496f-9efd-6fbc3ac73191" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-228a7024-422d-496f-9efd-6fbc3ac73191">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
import pandas as pd

# Create the data folder if it doesn't exist
os.makedirs('/content/Bill2Watt/data', exist_ok=True)

# Move the uploaded CSV into the data folder
os.rename('dataset.csv', '/content/Bill2Watt/data/dataset.csv')

# Confirm the file is there
print(os.listdir('/content/Bill2Watt/data'))

# Load the dataset
csv_file = '/content/Bill2Watt/data/dataset.csv'
df = pd.read_csv(csv_file)

# Quick look
print("Shape of dataset:", df.shape)
df.head()
# Out:
# ['dataset.csv']
# Shape of dataset: (1294, 1)
#   user;month;type;class;category;nd_j0;nd_j1;nd_j2;x_f1;x_f2;x_f3;y_i0;y_i1;y_i2;y_i3;y_i4;y_i5;y_i6;y_i7;y_i8;y_i9;y_i10;y_i11;y_i12;y_i13;y_i14;y_i15;y_i16;y_i17;y_i18;y_i19;y_i20;y_i21;y_i22;y_i23;y_i24;y_i25;y_i26;y_i27;y_i28;y_i29;y_i30;y_i31;y_i32;y_i33;y_i34;y_i35;y_i36;y_i37;y_i38;y_i39;y_i40;y_i41;y_i42;y_i43;y_i44;y_i45;y_i46;y_i47;y_i48;y_i49;y_i50;y_i51;y_i52;y_i53;y_i54;y_i55;y_i56;y_i57;y_i58;y_i59;y_i60;y_i61;y_i62;y_i63;y_i64;y_i65;y_i66;y_i67;y_i68;y_i69;y_i70;y_i71
# 0  bta5_6;1;bta;bta5;cultural_and_sports;20;4;7;2...
# 1  bta5_6;2;bta;bta5;cultural_and_sports;20;4;4;2...
# 2  bta5_6;3;bta;bta5;cultural_and_sports;23;4;4;2...
# 3  bta5_6;4;bta;bta5;cultural_and_sports;21;4;5;1...
# 4  bta5_6;5;bta;bta5;cultural_and_sports;21;4;6;2...

# %%
# Load dataset with semicolon separator
csv_file = '/content/Bill2Watt/data/dataset.csv'
df = pd.read_csv(csv_file, sep=';')  # <-- note sep=';'

# Quick look
print("Shape of dataset:", df.shape)
df.head()
# Out:
# Shape of dataset: (1294, 83)
#      user  month type class             category  nd_j0  nd_j1  nd_j2  \
# 0  bta5_6      1  bta  bta5  cultural_and_sports     20      4      7
# 1  bta5_6      2  bta  bta5  cultural_and_sports     20      4      4
# 2  bta5_6      3  bta  bta5  cultural_and_sports     23      4      4
# 3  bta5_6      4  bta  bta5  cultural_and_sports     21      4      5
# 4  bta5_6      5  bta  bta5  cultural_and_sports     21      4      6
#
#       x_f1     x_f2  ...     y_i62     y_i63     y_i64     y_i65     y_i66  \
# 0  221.760  191.148  ...  0.953714  1.928571  1.617000  1.294429  2.101715
# 1  224.623  181.216  ...  1.375500  1.903500  1.362000  1.841000  1.163250
# 2  276.134  195.086  ...  1.246250  2.691750  2.315750  1.038750  2.151000
# 3  186.458  184.092  ...  0.450200  0.450000  0.962600  0.855200  0.473800
# 4  205.442  161.405  ...  1.565500  1.519500  1.386833  1.268500  1.180500
#
#       y_i67     y_i68     y_i69    y_i70     y_i71
# ...

# %%
# Features start with 'x_' and targets start with 'y_'
x_cols = [col for col in df.columns if col.startswith('x_')]
y_cols = [col for col in df.columns if col.startswith('y_')]

X = df[x_cols].values
Y = df[y_cols].values

print("Feature shape:", X.shape)
print("Target shape:", Y.shape)
# Out:
# Feature shape: (1294, 3)
# Target shape: (1294, 72)

# %%
create_two_doughnuts(
    data=df,              # the full dataframe
    col_in='type',        # inner circle column
    col_out='category',   # outer circle column
    title='Distribution of Type and Category'
)

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])  # select only numbers

plt.figure(figsize=(10,8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Numeric Feature Correlation')
plt.show()
